# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading data
df=pd.read_csv('C:/Users/lenovo/Downloads/parkinsons.csv')

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df['status'].value_counts()
# 1 MEANS HAS PARKINSONS 
# 0 MEANS NO PARKINSON
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
df.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
sns.countplot(x='status',data=df)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
# SPLITING VALUES

# %%
X=df.drop(columns=['name','status'],axis=1)

# %%
y=df['status']

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=3)

# %%
scaler=StandardScaler() # USED TO UNDERSTAND NATURE OF DATA

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scaler.transform(X_train)#Converts all values in same range

X_test=scaler.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 1.10299226  0.18528751  1.72239961 ... -0.62085202 -0.75526411
#   -1.61274004]
#  [-0.0522716   3.52953182 -1.07850276 ...  0.46448548  0.87695615
#    0.80579918]
#  [-0.27531783 -0.37059958 -1.16068132 ... -0.79908454 -0.2790908
#   -0.29336491]
#  ...
#  [-0.82355342 -0.80845035 -0.26587083 ... -0.08336209  0.40134939
#   -0.41311377]
#  [ 1.07586469  0.4636441   1.32134361 ...  1.62910441  2.18892295
#    2.92373883]
#  [ 0.02593974 -0.35492749  0.63071577 ... -0.48269691 -0.68221787
#   -1.16286257]]

# %%
#MODEL TRAINING

# %%
#SUPPORT VECTOR MACHINE MODEL

# %%
model=svm.SVC(kernel='linear') # GOING TO CLASSIFY INTO PARKINSONS POSITIVE AND NEGATIVE PATIENTS.

# %%
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
#MODEL EVALUATION

# %%
#TRAINIGN DATA ACCURACY
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(y_train,X_train_prediction)

# %%
training_data_accuracy

#89.70% accuracy
# Out:
# 0.8970588235294118

# %%
# TEST DATA ACCURACY

# %%
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(y_test,X_test_prediction)

# %%
test_data_accuracy

#86.44% Accuracy
# Out:
# 0.864406779661017

# %%
# PREDICTIIVE SYSTEM

# %%
#CREATING TUPLE TO TAKE INPUT DATA

# %%
input_data=(131.16200,113.78700,0.00968,0.00008,0.00463,0.00750,0.01388,0.04701,0.45600,0.02328,0.03526,0.03243,0.06985,0.01222,21.37800,1,0.415564,0.825069,-4.242867,0.299111,2.187560,0.357775)

# %%
#CHANGING INPUT DATA TO NUMPY ARRAY
#BASICALLY CONVERTING TUPLE TO NUMPY ARRAY

# %%
input_data_as_numpy_array=np.asarray(input_data)

# %%
#WE ARE RESHAPING BECAUSE WE ARE GIVING ONE DATAPOINT. 

reshaped=input_data_as_numpy_array.reshape(1,-1)

# %%
#STANDARDIZING THE DATA

# %%
std_data=scaler.transform(reshaped)

# %%
prediction=model.predict(std_data)

#PREDICTING TARGET VALUE EITHER 0 OR 1

# %%
print(prediction)
if prediction[0] is 0:
    print('Negative,Parkinson Not Found')
else:
    print('Positive,Parkinson Found')
# Out:
# [0]
# Positive,Parkinson Found
